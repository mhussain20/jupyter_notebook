# %% [markdown]
# # Session 1: Homework
#
# Complete all sections.

# %% [markdown]
# 1. Create a directory called `CM6114` in your home directory (folder with your username)
# 2. Inside, create three folders:
#     1. `assignments` - where all homeworks and coursework will be saved
#     2. `lectures` - where all lectures will be saved
#     3. `work` - space for your own work, either as a `Python` script or a `Jupyter` notebook
# 3. Enter the work directory and write out the following code into a file called `age.py`, filling in the blanks - anywhere you see ###
#
# The goal is to print the following on the screen (with your name not Alex):
#
# ![exercise1.png](attachment:exercise1.png)

# %%
print("Hello")
print("Mohammed")
print("You have: " + str("3") + " awesome years of knowledge ahead of you")

# %% [markdown]
# Run the above code using `python age.py` in your command prompt/terminal
#
# 1. How could we make this code so as we dont have to manually enter the number but instead calculate it?
# We could use the year of graduation (2023) and the program can use the system clock year (2020) and subtract the two integers to display the number of years remaining on the course.
#
# 2. Why is there a `+` between "Have have: " and str()?
# Because we are using 'string concatenation' where we can join multiple strings together and this is a syntactical neccessity.
#
# 3. What do you think the `str` stands for on the last line? Why is it there?
# The str stands for 'string' and is used to declare the variable type, this is needed as you cannot use integers in string concatenation.
#
# 4. Find the documentation for print.
# https://docs.python.org/3/library/functions.html#print
#
# 5. **ADVANCED:** Call the print method with 3 arguments
#
# name = "mohammed"
# print("My name is ", name, "and I am ", 18, " years old")

# %% [markdown]
# Try to make some changes to the file and generate some errors.<br>
# i.e. remove one " from Hello <br>
# what happens?
#
# Document the different errors.

# %% [markdown]
# " is removed from one end of print statement
# EOL while scanning string literal
#
# str("") removed from str("3")
# TypeError: can only concatenate str (not "int") to str
